# %%
# !pip install llama-index-llms-huggingface-api llama-index-embeddings-huggingface
# Out:
# Collecting llama-index-llms-huggingface-api
#   Downloading llama_index_llms_huggingface_api-0.7.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.7.0-py3-none-any.whl.metadata (459 bytes)
# Requirement already satisfied: huggingface-hub>=0.31.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-llms-huggingface-api) (0.36.2)
# Collecting llama-index-core<0.15,>=0.13.0 (from llama-index-llms-huggingface-api)
#   Downloading llama_index_core-0.14.20-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.13.5)
# Collecting aiosqlite (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting banks<3,>=2.3.0 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading banks-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: dataclasses-json in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.6.7)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting dirtyjson<2,>=1.0.8 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2,>=1.2.0 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2026.2.0)
# Requirement already satisfied: httpx in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.28.1)
# Collecting llama-index-workflows<3,>=2.14.0 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading llama_index_workflows-2.17.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.6.1)
# Collecting nltk>=3.9.3 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (12.1.1)
# Requirement already satisfied: platformdirs in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (4.9.4)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.33.0)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.12.0)
# Collecting tinytag>=2.2.0 (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading tinytag-2.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.9.0)
# Requirement already satisfied: wrapt in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.22.0)
# Collecting griffe (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading griffe-2.0.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.1.6)
# Collecting llama-index-instrumentation>=0.4.3 (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading llama_index_instrumentation-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: idna>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.11)
# Collecting sentence-transformers>=2.6.1 (from llama-index-embeddings-huggingface)
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: filelock in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.31.0->llama-index-llms-huggingface-api) (3.25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.31.0->llama-index-llms-huggingface-api) (1.3.2)
# Requirement already satisfied: packaging>=20.9 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.31.0->llama-index-llms-huggingface-api) (24.1)
# Requirement already satisfied: click in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (8.1.8)
# Requirement already satisfied: joblib in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2026.4.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (2026.2.25)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: torch>=1.11.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.10.0)
# Requirement already satisfied: scikit-learn in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.2)
# Requirement already satisfied: scipy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# INFO: pip is looking at multiple versions of transformers to determine which version is compatible with other requirements. This could take a while.
#   Downloading transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
#   Using cached transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
#   Downloading transformers-5.2.0-py3-none-any.whl.metadata (32 kB)
#   Downloading transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.22.2)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface)
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting greenlet>=1 (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading greenlet-3.4.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Requirement already satisfied: sympy>=1.13.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.26.2)
# Collecting griffecli==2.0.2 (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading griffecli-2.0.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting griffelib==2.0.2 (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading griffelib-2.0.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting colorama>=0.4 (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-llms-huggingface-api) (3.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Downloading llama_index_llms_huggingface_api-0.7.0-py3-none-any.whl (7.5 kB)
# Downloading llama_index_core-0.14.20-py3-none-any.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 766.7 kB/s  0:00:15m0:00:0100:01
# Downloading banks-2.4.1-py3-none-any.whl (35 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading llama_index_workflows-2.17.3-py3-none-any.whl (111 kB)
# Downloading llama_index_embeddings_huggingface-0.7.0-py3-none-any.whl (8.9 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading llama_index_instrumentation-0.5.0-py3-none-any.whl (16 kB)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 776.6 kB/s  0:00:02 eta 0:00:01
# Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 702.5 kB/s  0:00:17m0:00:0100:01
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Downloading greenlet-3.4.0-cp312-cp312-macosx_11_0_universal2.whl (286 kB)
# Downloading tinytag-2.2.1-py3-none-any.whl (32 kB)
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Downloading griffe-2.0.2-py3-none-any.whl (5.1 kB)
# Downloading griffecli-2.0.2-py3-none-any.whl (9.5 kB)
# Downloading griffelib-2.0.2-py3-none-any.whl (142 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: filetype, dirtyjson, tinytag, safetensors, nltk, griffelib, greenlet, deprecated, colorama, aiosqlite, griffecli, llama-index-instrumentation, griffe, transformers, llama-index-workflows, banks, sentence-transformers, llama-index-core, llama-index-llms-huggingface-api, llama-index-embeddings-huggingface
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [llama-index-embeddings-huggingface]-core]mers]
# Successfully installed aiosqlite-0.22.1 banks-2.4.1 colorama-0.4.6 deprecated-1.3.1 dirtyjson-1.0.8 filetype-1.2.0 greenlet-3.4.0 griffe-2.0.2 griffecli-2.0.2 griffelib-2.0.2 llama-index-core-0.14.20 llama-index-embeddings-huggingface-0.7.0 llama-index-instrumentation-0.5.0 llama-index-llms-huggingface-api-0.7.0 llama-index-workflows-2.17.3 nltk-3.9.4 safetensors-0.7.0 sentence-transformers-5.3.0 tinytag-2.2.1 transformers-4.57.6
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login, whoami

load_dotenv(dotenv_path="../.env", override=True)
token = os.environ.get("HF_TOKEN")

# Validate before logging in
try:
    login(token=token, add_to_git_credential=False)
    user = whoami()
    print(f"✅ Logged in as: {user['name']}")
except Exception as e:
    print(f"❌ Login failed: {e}")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ Logged in as: zaidalissa

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
import os

llm = HuggingFaceInferenceAPI(
    model_name="Qwen/Qwen2.5-Coder-32B-Instruct",
    temperature=0.7,
    max_tokens=100,
    token=token,
    provider="auto"
)

response = llm.complete("Hello, how are you?")
print(response)
# I am good, how can I help you today?
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with whatever you need. How can I assist you today?
