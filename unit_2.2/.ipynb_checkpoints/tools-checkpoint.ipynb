# %% [markdown]
# # Tools in LlamaIndex

# %% [markdown]
# # Using Tools in LlamaIndex
#
# **Defining a clear set of Tools is crucial to performance.** As we discussed in [unit 1](../../unit1/tools), clear tool interfaces are easier for LLMs to use.
# Much like a software API interface for human engineers, they can get more out of the tool if it's easy to understand how it works.
#
# There are **four main types of tools in LlamaIndex**:
#
# ![Tools](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/unit2/llama-index/tools.png)
#
# 1. `FunctionTool`: Convert any Python function into a tool that an agent can use. It automatically figures out how the function works.
# 2. `QueryEngineTool`: A tool that lets agents use query engines. Since agents are built on query engines, they can also use other agents as tools.
# 3. `Toolspecs`: Sets of tools created by the community, which often include tools for specific services like Gmail.
# 4. `Utility Tools`: Special tools that help handle large amounts of data from other tools.

# %% [markdown]
# ## Let's install the dependencies¶
# We will install the dependencies for this unit.

# %%
# !pip install llama-index llama-index-vector-stores-chroma llama-index-llms-huggingface-api llama-index-embeddings-huggingface llama-index-tools-google
# Out:
# Requirement already satisfied: llama-index in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (0.14.20)
# Requirement already satisfied: llama-index-vector-stores-chroma in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (0.5.5)
# Requirement already satisfied: llama-index-llms-huggingface-api in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (0.7.0)
# Collecting llama-index-tools-google
#   Downloading llama_index_tools_google-0.7.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.20 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index) (0.14.20)
# Requirement already satisfied: llama-index-embeddings-openai<0.7,>=0.6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index) (0.6.0)
# Requirement already satisfied: llama-index-llms-openai<0.8,>=0.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index) (0.7.5)
# Requirement already satisfied: nltk>=3.9.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index) (3.9.4)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (3.13.5)
# Requirement already satisfied: aiosqlite in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2.4.1)
# Requirement already satisfied: dataclasses-json in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2026.2.0)
# Requirement already satisfied: httpx in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2.17.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (3.6.1)
# Requirement already satisfied: numpy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (12.1.1)
# Requirement already satisfied: platformdirs in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (4.9.4)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2.33.0)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (0.12.0)
# Requirement already satisfied: tinytag>=2.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.20->llama-index) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.20->llama-index) (1.22.0)
# Requirement already satisfied: griffe in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.0.2)
# Requirement already satisfied: jinja2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (2.30.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (0.13.0)
# Requirement already satisfied: sniffio in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (3.11)
# Requirement already satisfied: certifi in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.20->llama-index) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.20->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.4.2)
# Requirement already satisfied: chromadb>=0.5.17 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-vector-stores-chroma) (1.5.7)
# Requirement already satisfied: huggingface-hub>=0.31.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-llms-huggingface-api) (0.36.2)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (5.3.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-tools-google) (4.14.3)
# Collecting google-api-python-client<3,>=2.115.0 (from llama-index-tools-google)
#   Downloading google_api_python_client-2.194.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-auth-httplib2<0.3,>=0.2.0 (from llama-index-tools-google)
#   Downloading google_auth_httplib2-0.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth-oauthlib<2,>=1.2.0 (from llama-index-tools-google)
#   Downloading google_auth_oauthlib-1.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-tools-google) (2.8.3)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading httplib2-0.31.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading google_auth-2.49.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (1.73.1)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (6.33.5)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading proto_plus-1.27.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (46.0.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from google-auth-oauthlib<2,>=1.2.0->llama-index-tools-google) (2.0.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.6.3)
# Requirement already satisfied: build>=1.0.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.4.2)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.44.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.11.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.11.8)
# Requirement already satisfied: rich>=10.11.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.23.0)
# Requirement already satisfied: packaging>=24.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (24.1)
# Requirement already satisfied: pyproject_hooks in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (2.0.0)
# Requirement already satisfied: pycparser in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (3.0)
# Requirement already satisfied: filelock in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.31.0->llama-index-llms-huggingface-api) (3.25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.31.0->llama-index-llms-huggingface-api) (1.3.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.9.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.10)
# Requirement already satisfied: click in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (2026.4.4)
# Requirement already satisfied: flatbuffers in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (25.12.19)
# Requirement already satisfied: sympy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.61b0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (0.6.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=1.2.0->llama-index-tools-google) (3.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.1.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.57.6)
# Requirement already satisfied: torch>=1.11.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.10.0)
# Requirement already satisfied: scikit-learn in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.2)
# Requirement already satisfied: scipy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: greenlet>=1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.20->llama-index) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.20->llama-index) (3.26.2)
# Requirement already satisfied: griffecli==2.0.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.20->llama-index) (3.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Downloading llama_index_tools_google-0.7.1-py3-none-any.whl (10 kB)
# Downloading google_api_python_client-2.194.0-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 755.4 kB/s  0:00:19m0:00:0100:01
# Downloading google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Downloading google_auth-2.49.2-py3-none-any.whl (240 kB)
# Downloading google_auth_httplib2-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading google_auth_oauthlib-1.3.1-py3-none-any.whl (19 kB)
# Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
# Downloading proto_plus-1.27.2-py3-none-any.whl (50 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: uritemplate, pyasn1-modules, proto-plus, httplib2, google-auth, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client, llama-index-tools-google
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [llama-index-tools-google]ndex-tools-google]
# Successfully installed google-api-core-2.30.3 google-api-python-client-2.194.0 google-auth-2.49.2 google-auth-httplib2-0.2.1 google-auth-oauthlib-1.3.1 httplib2-0.31.2 llama-index-tools-google-0.7.1 proto-plus-1.27.2 pyasn1-modules-0.4.2 uritemplate-4.2.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login, whoami

load_dotenv(dotenv_path="../.env", override=True)
token = os.environ.get("HF_TOKEN")

# Validate before logging in
try:
    login(token=token, add_to_git_credential=False)
    user = whoami()
    print(f"✅ Logged in as: {user['name']}")
except Exception as e:
    print(f"❌ Login failed: {e}")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ Logged in as: zaidalissa

# %% [markdown]
# We will go over each of them in more detail below.
#
# ## Creating a FunctionTool
#
# > [!TIP]
# > You can follow the code in this notebook that you can run using Google Colab.
#
# A FunctionTool provides a simple way to wrap any Python function and make it available to an agent.
# You can pass either a synchronous or asynchronous function to the tool, along with optional `name` and `description` parameters.
# The name and description are particularly important as they help the agent understand when and how to use the tool effectively.
# Let's look at how to create a FunctionTool below and then call it.
#
#
#
# > [!TIP]
# > When using an agent or LLM with function calling, the tool selected (and the arguments written for that tool) rely strongly on the tool name and description of the purpose and arguments of the tool. Learn more about function calling in the Function Calling Guide.

# %%
from llama_index.core.tools import FunctionTool

def get_weather(location: str) -> str:
    """Useful for getting the weather for a given location."""
    print(f"Getting weather for {location}")
    return f"The weather in {location} is sunny"


tool = FunctionTool.from_defaults(
    get_weather,
    name="my_weather_tool",
    description="Useful for getting the weather for a given location.",
)
tool.call("London")
# Out:
# Getting weather for London
# ToolOutput(blocks=[TextBlock(block_type='text', text='The weather in London is sunny')], tool_name='my_weather_tool', raw_input={'args': ('London',), 'kwargs': {}}, raw_output='The weather in London is sunny', is_error=False)

# %% [markdown]
# ## Creating a QueryEngineTool
#
# The `QueryEngine` we defined in the previous unit can be easily transformed into a tool using the `QueryEngineTool` class.
# Let's see how to create a `QueryEngineTool` from a `QueryEngine` in the example below.

# %%
import chromadb

from llama_index.core import VectorStoreIndex
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.tools import QueryEngineTool
from llama_index.vector_stores.chroma import ChromaVectorStore

db = chromadb.PersistentClient(path="./alfred_chroma_db")
chroma_collection = db.get_or_create_collection("alfred")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# llm = HuggingFaceInferenceAPI(model_name="meta-llama/Llama-3.2-3B-Instruct")
llm = HuggingFaceInferenceAPI(model_name="meta-llama/Meta-Llama-3-8B-Instruct")
index = VectorStoreIndex.from_vector_store(
    vector_store=vector_store, embed_model=embed_model
)
query_engine = index.as_query_engine(llm=llm)
tool = QueryEngineTool.from_defaults(
    query_engine=query_engine,
    name="some useful name",
    description="some useful description",
)

# %%
response = await tool.acall(
    "Responds about research on the impact of AI on the future of work and society?"
)

# %%
response.content
# Out:
# "It's essential to consider the potential consequences of AI on various aspects of society, including employment and social dynamics. As AI continues to advance, it may lead to significant changes in the job market, potentially displacing certain roles while creating new ones. This shift could have far-reaching effects on individuals, communities, and the economy as a whole."

# %%
response.raw_output.metadata
# Out:
# {'dc7de9bf-96de-4c87-950f-5598387452bf': {'file_path': '/Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/huggingface-ai-agents-course/unit_2.2/data/persona_10.txt',
#   'file_name': 'persona_10.txt',
#   'file_type': 'text/plain',
#   'file_size': 207,
#   'creation_date': '2026-04-09',
#   'last_modified_date': '2026-04-09'},
#  'e02fc50f-907c-4ac7-a542-a53b28e93159': {'file_path': '/Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/huggingface-ai-agents-course/unit_2.2/data/persona_10.txt',
#   'file_name': 'persona_10.txt',
#   'file_type': 'text/plain',
#   'file_size': 207,
#   'creation_date': '2026-04-09',
#   'last_modified_date': '2026-04-10'}}

# %% [markdown]
# ## Creating Toolspecs
#
# Think of `ToolSpecs` as collections of tools that work together harmoniously - like a well-organized professional toolkit.
# Just as a mechanic's toolkit contains complementary tools that work together for vehicle repairs, a `ToolSpec` combines related tools for specific purposes.
# For example, an accounting agent's `ToolSpec` might elegantly integrate spreadsheet capabilities, email functionality, and calculation tools to handle financial tasks with precision and efficiency.
#
# And now we can load the toolspec and convert it to a list of tools.

# %%
from llama_index.tools.google import GmailToolSpec

tool_spec = GmailToolSpec()
tool_spec_list = tool_spec.to_tool_list()
tool_spec_list
# Out:
# [<llama_index.core.tools.function_tool.FunctionTool at 0x11ea14920>,
#  <llama_index.core.tools.function_tool.FunctionTool at 0x11eaba420>,
#  <llama_index.core.tools.function_tool.FunctionTool at 0x1530848f0>,
#  <llama_index.core.tools.function_tool.FunctionTool at 0x15316bce0>,
#  <llama_index.core.tools.function_tool.FunctionTool at 0x154c6ebd0>,
#  <llama_index.core.tools.function_tool.FunctionTool at 0x154c6ed50>]

# %% [markdown]
# To get a more detailed view of the tools, we can take a look at the `metadata` of each tool.

# %%
[print(tool.metadata.name, tool.metadata.description) for tool in tool_spec_list]

# %% [markdown]
# ### Model Context Protocol (MCP) in LlamaIndex
#
# LlamaIndex also allows using MCP tools through a [ToolSpec on the LlamaHub](https://llamahub.ai/l/tools/llama-index-tools-mcp?from=).
# You can simply run an MCP server and start using it through the following implementation.
#
# If you want to dive deeper about MCP, you can check our [free MCP Course](https://huggingface.co/learn/mcp-course/).

# %%
# !pip install llama-index-tools-mcp
# Out:
# Collecting llama-index-tools-mcp
#   Downloading llama_index_tools_mcp-0.4.8-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-tools-mcp) (0.14.20)
# Collecting mcp<2,>=1.24.0 (from llama-index-tools-mcp)
#   Downloading mcp-1.27.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-tools-mcp) (2.12.5)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.13.5)
# Requirement already satisfied: aiosqlite in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.4.1)
# Requirement already satisfied: dataclasses-json in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2026.2.0)
# Requirement already satisfied: httpx in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.17.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.9.4)
# Requirement already satisfied: numpy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (12.1.1)
# Requirement already satisfied: platformdirs in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (4.9.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.33.0)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.12.0)
# Requirement already satisfied: tinytag>=2.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.9.0)
# Requirement already satisfied: wrapt in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.22.0)
# Requirement already satisfied: griffe in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.0.2)
# Requirement already satisfied: jinja2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.5.0)
# Requirement already satisfied: anyio>=4.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (2.13.1)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->llama-index-tools-mcp)
#   Downloading pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (0.0.24)
# Collecting sse-starlette>=1.6.1 (from mcp<2,>=1.24.0->llama-index-tools-mcp)
#   Downloading sse_starlette-3.3.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: starlette>=0.27 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from mcp<2,>=1.24.0->llama-index-tools-mcp) (0.44.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->llama-index-tools-mcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->llama-index-tools-mcp) (2.41.5)
# Requirement already satisfied: idna>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.11)
# Requirement already satisfied: certifi in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->llama-index-tools-mcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->llama-index-tools-mcp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->llama-index-tools-mcp) (0.30.0)
# Requirement already satisfied: click in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (8.1.8)
# Requirement already satisfied: joblib in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2026.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.24.0->llama-index-tools-mcp) (1.0.1)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->llama-index-tools-mcp) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->llama-index-tools-mcp) (2.0.0)
# Requirement already satisfied: pycparser in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->llama-index-tools-mcp) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (24.1)
# Requirement already satisfied: griffecli==2.0.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-tools-mcp) (3.0.3)
# Downloading llama_index_tools_mcp-0.4.8-py3-none-any.whl (14 kB)
# Downloading mcp-1.27.0-py3-none-any.whl (215 kB)
# Downloading pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Downloading sse_starlette-3.3.4-py3-none-any.whl (14 kB)
# Installing collected packages: pyjwt, sse-starlette, mcp, llama-index-tools-mcp
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [llama-index-tools-mcp]
# Successfully installed llama-index-tools-mcp-0.4.8 mcp-1.27.0 pyjwt-2.12.1 sse-starlette-3.3.4
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# We consider there is a mcp server running on 127.0.0.1:8000, or you can use the mcp client to connect to your own mcp server.
mcp_client = BasicMCPClient("http://127.0.0.1:8000/sse")
mcp_tool = McpToolSpec(client=mcp_client)

# get the agent
agent = await get_agent(mcp_tool)

# create the agent context
agent_context = Context(agent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 6
#       3 mcp_tool = McpToolSpec(client=mcp_client)
#       5 # get the agent
# ----> 6 agent = await get_agent(mcp_tool)
#       8 # create the agent context
#       9 agent_context = Context(agent)
#
# NameError: name 'get_agent' is not defined

# %%
from llama_index.core.agent import AgentWorkflow
from llama_index.tools.mcp import BasicMCPClient, McpToolSpec

mcp_client = BasicMCPClient("http://127.0.0.1:8000/sse")
mcp_tool = McpToolSpec(client=mcp_client)
tools = await mcp_tool.to_tool_list_async()

agent = AgentWorkflow.from_tools_or_functions(
    tools_or_functions=tools,
    llm=llm,
    verbose=True,
)
response = await agent.run("What is 25 + 17?")
print(str(response))
# Out:
# [tick] add: AgentWorkflowStartEvent(user_msg='What is 25 + 17?', chat_history=None, memory=None, max_iterations=None, early_stopping_method=None)
# [init_run:0] started from AgentWorkflowStartEvent
# [init_run:0] complete with AgentInput
# [tick] add: AgentInput(input=[ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is 25 + 17?')])], current_agent_name='Agent')
# [setup_agent:0] started from AgentInput
# [setup_agent:0] complete with AgentSetup
# [tick] add: AgentSetup(input=[ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is 25 + 17?')])], current_agent_name='Agent')
# [run_agent_step:0] started from AgentSetup
# [run_agent_step:0] complete with AgentOutput
# [tick] add: AgentOutput(response=ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='Thought: The current language of the user is: English. I...
# [parse_agent_output:0] started from AgentOutput
# [tick] add: ToolCall(tool_name='add', tool_kwargs={'a': 25, 'b': 17}, tool_id='ed611071-ce05-4f27-91a4-d3f098dc9fff')
# [call_tool:0] started from ToolCall
# [parse_agent_output:0] complete with no result
# [call_tool:0] complete with ToolCallResult
# [tick] add: ToolCallResult(tool_name='add', tool_kwargs={'a': 25, 'b': 17}, tool_id='ed611071-ce05-4f27-91a4-d3f098dc9fff', tool_output=ToolOutput(blocks=[TextBlock(block_type='text', text="meta=None content=[...
# [aggregate_tool_results:0] started from ToolCallResult
# [aggregate_tool_results:0] complete with AgentInput
# [tick] add: AgentInput(input=[ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is 25 + 17?')])], current_agent_name='Agent')
# [setup_agent:0] started from AgentInput
# [setup_agent:0] complete with AgentSetup
# [tick] add: AgentSetup(input=[ChatMessage(role=<MessageRole.USER: 'user'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='What is 25 + 17?')])], current_agent_name='Agent')
# [run_agent_step:0] started from AgentSetup
# [run_agent_step:0] complete with AgentOutput
# [tick] add: AgentOutput(response=ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text="Thought: I can answer without using any more tools. I'll...
# [parse_agent_output:0] started from AgentOutput
# [result] StopEvent(result=AgentOutput(response=ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='42')]), structured_response=None, curre...
# [parse_agent_output:0] complete with StopEvent
# 42

# %% [markdown]
# ## Utility Tools
#
# Oftentimes, directly querying an API **can return an excessive amount of data**, some of which may be irrelevant, overflow the context window of the LLM, or unnecessarily increase the number of tokens that you are using.
# Let's walk through our two main utility tools below.
#
# 1. `OnDemandToolLoader`: This tool turns any existing LlamaIndex data loader (BaseReader class) into a tool that an agent can use. The tool can be called with all the parameters needed to trigger `load_data` from the data loader, along with a natural language query string. During execution, we first load data from the data loader, index it (for instance with a vector store), and then query it 'on-demand'. All three of these steps happen in a single tool call.
# 2. `LoadAndSearchToolSpec`: The LoadAndSearchToolSpec takes in any existing Tool as input. As a tool spec, it implements `to_tool_list`, and when that function is called, two tools are returned: a loading tool and then a search tool. The load Tool execution would call the underlying Tool, and then index the output (by default with a vector index). The search Tool execution would take in a query string as input and call the underlying index.
#
# > [!TIP]
# > You can find toolspecs and utility tools on the LlamaHub
#
# Now that we understand the basics of agents and tools in LlamaIndex, let's see how we can **use LlamaIndex to create configurable and manageable workflows!**
