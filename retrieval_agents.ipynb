# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login, whoami

load_dotenv(dotenv_path=".env", override=True)
token = os.environ.get("HF_TOKEN")

# Validate before logging in
try:
    login(token=token, add_to_git_credential=False)
    user = whoami()
    print(f"✅ Logged in as: {user['name']}")
except Exception as e:
    print(f"❌ Login failed: {e}")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ Logged in as: zaidalissa

# %% [markdown]
# ## Basic Retrieval with WebSerach
# Let's build a simple agent that can search the web. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# 1. Search for latest superhero party trends
# 2. Refine results to include luxury elements
# 3. Synthesize information into a complete plan
#
#
# Here's how Alfred's agent can achieve this:

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",  # Non-thinking variant, supports tool calling
    # token="hf_..."  # Add your HF token if hitting auth errors
)

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = model

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   luxury_superhero_party_ideas = web_search("luxury superhero-themed party ideas including decorations,
#   entertainment, and catering")
#   print(luxury_superhero_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Birthday Party Packages at BIR Luxury Homes | Celebrate in
# Style](https://birluxurylanding.com/birthday-party-packages/)
# We offer all-inclusive packages with all the frillsandflourishes ofthemeddecorationsto gourmetcatering, so you can
# just sit back, relax,and...
#
# [30 Elegant Christmas Party Themes & Ideas for a
# Stylish](https://www.catchmyparty.com/blog/elegant-christmas-party-themes)
# Timeless HolidayLuxuryThese glamorous Christmaspartythemes channel classic seasonal style — rich textures, glowing
# candlelight,andrefined ...
#
# [5 Unique Employee Appreciation Party Ideas - PMCAOnline](https://pmcaonline.org/employee-party-ideas/)
# ...andto finish their tasks, so why don’t you make apartywhere your employees can dress up as their
# favoritesuperhero? You can even have trivia ...
#
# [Wedding & Party Network - Online wedding, special event
# and](https://www.weddingandpartynetwork.com/blog/tag/themed-parties/)
# ...themedpartythis summer? Here are a few tipsandideas... We hope theseideashelpandyou have some fun inspiration
# for your beachthemedparty.
#
# [300+ Party Decoration Ideas for Memorable Celebrations
# -](https://www.shinny-party.com/blog/300+-party-decoration-ideas-for-memorable-celebrations-pinterest-2020/)
# ...partybut struggling to come up with uniqueandcreativedecorationideas? Look no further than Pinterest for endless
# inspiration! With over 300ideas...
#
# [Best 23 Backyard Party Menu Ideas - Home, Family, Style and
# Art](https://coolandfantastic.com/backyard-party-menu-ideas/)
# Best 23 BackyardPartyMenuIdeas.The most effective kind of backyard celebration has sharp exterior d cor
# suggestionsandenjoyable exterior tasks ...
#
# [Party Themes: Top Picks for Fun and Memorable Events |
# BrainFall](https://brainfall.com/articles/party-themes-top-picks-for-fun-and-memorable-events/)
# Partythemes not only give your celebration direction, but they also make it easier to coordinatedecorations,
# food,andentertainment, ensuring a ...
#
# [10 Corporate Party Themes Your Team Will
# Love](https://www.aokevents.com/10-corporate-party-themes-your-team-will-love/)
# A well-executed theme doesn ’ t just provide visual appeal; it drives the entire experience, from
# thecateringandentertainmentto the dress ...
#
# [Corporate event themes Archives - Partyinkers](https://www.partyinkers.com/tag/corporate-event-themes/)
# The relaxed nature of this theme makes it perfect for summerpartiesor mid-year celebrations, providing a break from
# the routineandan opportunity ...
#
# [Parties | Venue Hire | Theme Parties | Birthday Parties |](https://www.animalmagicfamily.co.uk/party-venue-hire)
# Why not go one step furtherandhave us organise athemedpartyfor you? We specialise in planning horrorandmovie scene
# settings so whether you re ...
#
# Out: None
# [Step 1: Duration 6.88 seconds| Input tokens: 2,091 | Output tokens: 101]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   luxury_superhero_party_ideas_refined = web_search("luxury superhero-themed party ideas")
#   print(luxury_superhero_party_ideas_refined)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [5 Superhero Themed Party Ideas | The Silent Disco
# Company](https://thesilentdiscocompany.co.uk/blog/top-5-superhero-themed-party-ideas/)
# August 6, 2024 -Kick off your superhero-themed party with aclassic costume party. Invite your guests to dress up as
# their favourite superheroes or villains, and set up a photo booth with themed props for memorable snapshots.
#
# [Superhero Party Supplies | Meri Meri – Meri Meri UK](https://merimeri.co.uk/collections/super-hero)
# Make a dramatic super heroes themed party with our fabulous plates, cups, napkins, garlands and cake toppers.
#
# [Superhero Party Supplies | Superhero Party Decorations | Party
# Delights](https://www.partydelights.co.uk/kids-party/superhero-party-supplies)
# Shop superhero party bags, plates, balloons, piñatas and superhero-inspired fancy dress - suitable for heroes big
# and small! Whether you’re saving Gotham with Batman, assembling your team with The Avengers or unleashing your
# spidey sense with Spiderman we’ve got the perfect superhero party ideas for the occasion.
#
# [Superhero Party - Party Supplies | Party Packs](https://www.partypacks.co.uk/collections/superhero-party)
# Whether you're a fan of the ... spectacular superhero themed party; includingmarvel party decorations, fancy dress
# costumes, disposable tableware and superhero party bags!...
#
# [Super Hero Theme - Superhero Party Decorations - Party Pieces For All Ages – The Original Party Bag
# Company](https://theoriginalpartybagcompany.co.uk/collections/super-hero-theme)
# Black honeycomb ball for all birthday parties, for halloween or pirates or for a chic party or wedding! ... Justice
# League Happy Birthday decoration. Large jointed letter banner featuring all your favourite characters. "Close
# (esc)" ... This pack contains cups designed with a comic style print of the Justice League featuring some of your
# favourite characters including Wonder Woman and Batman. Team with the rest of the justice league range for a fun
# superhero themed party!
#
# [Superhero Party Decorations | Cool Kids Party Supplies – Pretty Little Party
# Shop](https://prettylittlepartyshop.co.uk/collections/superhero-party)
# Combine primary colours to create a super bright party that shouts 'KaPow'!
#
# [Superhero Themed Party Ideas | Superhero Parties](https://www.thelittlethings.co.uk/collections/superhero-1)
# Kids love a superhero themed party, it gives them the chance to dress up and have fun. AtThe Little Thingswe have
# tableware, decorations and party bags
#
# [Superhero Party Supplies | Partyrama](https://www.partyrama.co.uk/themes/superheros-party-supplies/)
# Each theme is packed with awesome plates, cups, napkins, balloons, decorations, party bags, toys, games and lots
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# For instance, you can center your celebration aroundSpider-Man with web-themed decorations, Spider-Man-shaped
# cookies, and even a Spider-Man-themed cake. ... The centerpiece of any superhero party is the ...
#
# [24 Incredible Superhero Party Ideas that Will Make You Wish You Were a Kid
# Again!](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# June 19, 2024 -24 incredible superhero party ideas that kids will love and make adults wish they were kids again.
# From decor ideas, party foods, and costume ideas to superhero-themed activities, we have all of your party needs
# covered.
#
# Out: None
# [Step 3: Duration 7.26 seconds| Input tokens: 8,968 | Output tokens: 272]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result_decor = web_search("luxury superhero-themed party decorations")
#   print("Luxury superhero-themed party decorations:", result_decor)
#
#   result_entertainment = web_search("luxury superhero-themed party entertainment")
#   print("Luxury superhero-themed party entertainment:", result_entertainment)
#
#   result_catering = web_search("luxury superhero-themed party catering")
#   print("Luxury superhero-themed party catering:", result_catering)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Luxury superhero-themed party decorations: ## Search Results
#
# [Superhero Home Decor For Themed Rooms &
# Parties](https://www.home-designing.com/superhero-decor-for-bedroom-living-bathroom)
# Many are inexpensive enough to work asthemedpartydecorations, while others would make wonderful gifts for dedicated
# and knowledgeable collectors.
#
# [Ideas for hosting a themed costume party - Biz News
# Reporter](https://biznewsreporter.com/ideas-for-hosting-a-themed-costume-party/)
# ... experienced weddingpartycoordination expert can assist with everything from selecting a theme, finding the
# perfect venue, coordinatingdecorations...
#
# [Creative Party Themes That Will Wow Your
# Guests](https://www.anitadee.com/blog/creative-party-themes-that-will-wow-your-guests/)
# Superheroesare all the rage these days, and asuperhero-themedpartyis a surefire hit for kids and adults alike.
# ...superheroand set the stage ...
#
# [Superhero Party Planner Made Super Simple](https://www.drevio.com/superhero-party-planner-made-super-simple)
# MarvelSuperheroes: This Marvel-themedparty... Use primary colors like red, blue, and yellow for yourpartydecor to
# create asuperherotheme.
#
# [Party Decorations - Luxury Party Decorations - Pretty
# Party](https://theoriginalpartybagcompany.co.uk/collections/decorations?page=2)
# This fun Pinata is shaped as Captain America's shield and is perfect for decorating a Marvel
# orsuperherothemedparty.
#
# [Party Decorations - Luxury Party Decorations - Pretty
# Party](https://theoriginalpartybagcompany.co.uk/collections/decorations?page=13)
# ...SuperheroPaper Fandecorations, perfect at asuperherothemedparty... This fun Superman Pinata is perfect for
# decorating asuperherothemedparty.
#
# [Superhero Party Supplies & Favors – Daydream
# Society](https://daydreamsociety.com/collections/superhero-collection)
# Leap into action with ourSuperheropartyessentials! Equip your event with heroically-themedpartyplates
# ,superherocups , and hangingdecorations...
#
# [23 Awesome Costume Party Ideas for Large-Scale Events](https://www.eventbrite.com/blog/costume-party-ideas/)
# town! Learn new skills, master awesome moves, and put your superhero knowledge to the test as a superhero of your
# choice and our designated party host take you on a thrilling, fun-filled 2-hour super adventure.
#
# [Superhero Party Package - Lil Me Entertainments](https://lilmeentertainments.co.uk/superhero-party-package/)
# July 11, 2024 -Superhero Party Packageis a perfect party for any superhero fan. Add Spiderman, Iron Man, Hulk,
# Batman or Captain America to your party.
#
# [Superhero Party | Superhero Entertainers | Superhero Birthday
# Parties](https://bellaparties.co.uk/party/superhero/)
# March 24, 2025 -You can choose from one of our specially themed and designed parties, or we can specially create
# something bespoke for you. Our parties include a fantasticBella Partiesentertainer, glitter tattoos, prizes, pass
# the parcel, balloon modelling ...
#
# [A Superhero World 🌎 – Live Themed Unique 🥳 Party Packages🤩](https://www.asuperheroworld.co.uk/)
# Get ready for an epic 2-hour celebration! Picture this: a themed Spiderman bouncy castle, fun games, amazing
# balloon modelling, and disco music that’ll keep the party going all night long, Plus, to make it extra special,
# your child’s favorite Spiderman will make a special appearance🤩 £350
#
# [Superhero Party Hire In Bromley Dartford Sidcup And Kent - Mascot Hire & Children's Parties | London,
# Kent](https://www.mascotmoments.com/products/superhero-party.php)
# Superhero Mascot Appearance - Your child's favourite hero joins the party ... Games, Prizes and Dancing - From hero
# training to dance battles! Bubble Machine and Disco Lights - Add a wow factor to the atmosphere · Confetti Shooter
# - A grand finale for the superhero experience · You can also add on extras like a themed superhero bouncy castle,
# party decorations, and more to complete your event setup.
# Luxury superhero-themed party catering: ## Search Results
#
# [Spider-Man - Wikipedia](https://en.wikipedia.org/wiki/Spider-Man)
# Marvel Comicssuperhero. This article is about the main and original version of thesuperhero. For other uses, see
# Spider-Man (disambiguation).Personality andthemes. "People often say glibly that Marvel succeeded by
# blendingsuperheroadventure stories with soap opera.
#
# [TrendingPartyThemesand HowCaterersin Lake Macquarie
# Can...](https://www.apsense.com/article/trending-party-themes-and-how-caterers-in-lake-macquarie-can-bring-them-to-
# life.html)
# Partycateringin Lake Macquarie could includehero-themeddishes such as 'Power-Up Pizzas' with superhero insignias,
# 'Kryptonite' cupcakes with green frosting, and 'Hero Sandwiches' with a variety of fillings.
#
# [Max & Madeline’s Princess &
# SuperheroesParty|Superheroparty...](https://www.pinterest.com/pin/max-madelines-princess-superheroes-party--2983641
# 6276965836/)
# Vibrant Superhero Backdrop. FantasyParty.CateringOptions. Food Stands.SuperheroThemedArchPartyEntrance from a DC vs
# Marvel: Battle of the Universe Superhero BirthdayPartyon Kara'sPartyIdeas | KarasPartyIdeas.com (17).
#
# [How to Choose the Best KidsPartyCateringin... - Your Private
# Chef](https://www.yourprivatechef.com.au/blog/kids-party-catering-in-melbourne/)
# Caterersoffering kidspartycateringoften providethemedmenu options that match the overall aesthetic of theparty.
# From princess and piratethemestosuperheroand animalthemes, the food can become part of theparty’s entertainment.
#
# [Let’s have athemedpartycateringservice: enjoy the
# show](https://www.owenbrotherscatering.com/blog/post/lets-have-a-themed-party-catering-service-enjoy-the-show)
# Some of the time the correctcateringis all that is required. When arranging athemedoccasion, rather than running
# hard and fast with a stylistic layout, let yourcatererconvey thethemeunpretentiously by means of the bar or food.
#
# [Lyn & Louise |Cateringfor Special Occasions | Houston Texas Area](https://www.lynandlouise.com/specialoccasions)
# Ourthemedpartycateringis perfect for those who want to add a unique touch to their special occasion.Experience the
# ultimate inluxurydining with our Sailboat Epicurean Excursions. Savor the flavor of the sea while enjoying the
# stunning views from our sailboat.
#
# [Amazon.com: USERTEN 81pcs Red Spider
# WebSuperheroSupplies...](https://www.amazon.com/USERTEN-Superhero-10-Person-Disposable-Decorations/dp/B0CLR2Q9ZB)
# Product information. Theme. Spider. Occasion. birthday, halloween, superheroparty. Cartoon Character.Are you
# thinking of hosting asuperhero-themedparty? Our Red Spider Web Superhero Supplies are exactly what you need for an
# exciting, fun-filled celebration!
#
# [The Wandering TeaParty's Vendor Listing | Catch
# MyParty](https://www.catchmyparty.com/vendors/the-wandering-tea-party)
# About The Wandering TeaParty. We supply traditional afternoon tea orthemedpartycatering, as well
# asthemeddecorations, setup and hosting across Nottinghamshire, Lincolnshire and Rutland areas.
#
# [Brainstorming for asuperhero-themedparty. Pretty sure I want to
# be...](https://twitter.com/DaisiestDaisy/status/348171627806212096)
# Brainstorming for asuperhero-themedparty. Pretty sure I want to be either the Red Bee or Superman's Pal Jimmy Olsen
# #equallyamazingoptions.
#
# [FUNKY MINI BUFFETCATERINGFOR INTIMATE... |
# Medium](https://medium.com/@captainshrimp7/funky-mini-buffet-catering-for-intimate-occasions-in-klang-valley-df22ff
# b2010e)
# ThemedPartyCateringwith Good Friends & Colleagues in Kuala Lumpur. When you’re getting together with friends,
# consider focusing thepartydecor and food on a specifictheme.
#
# Out: None
# [Step 4: Duration 12.44 seconds| Input tokens: 13,949 | Output tokens: 419]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting information from relevant sources
#   decorations_info = [
#       "Dramatic superhero-themed party decorations from Meri Meri",
#       "Superhero paperfan decorations from The Original Party Bag Company",
#       "Superhero-themed party bags and plate ware from Daydream Society",
#       "Themed bouncy castle, games, balloon modeling, and disco music from A Superhero World"
#   ]
#
#   entertainment_info = [
#       "Interactive superhero games with Spider-Man, Batman, Superman, etc., from Absolutely Amazing Parties",
#       "Superhero-themed party host with games, prizes, and dancing from Bella Parties",
#       "Superhero mascots appearances and activities from Mascot Moments"
#   ]
#
#   catering_info = [
#       "Hero-themed dishes such as 'Power-Up Pizzas' with superhero insignias",
#       "Kryptonite cupcakes with green frosting",
#       "Hero sandwiches with a variety of fillings",
#       "Luxury dining experiences from Lyn & Louise in Houston",
#       "Funky mini buffet catering with themed food options"
#   ]
#
#   # Compiling the information into a single dictionary
#   luxury_superhero_party_ideas = {
#       "decorations": decorations_info,
#       "entertainment": entertainment_info,
#       "catering": catering_info
#   }
#
#   # Printing the compiled information
#   print(luxury_superhero_party_ideas)
#
#   # Final answer presentation
#   final_answer(luxury_superhero_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'decorations': ['Dramatic superhero-themed party decorations from Meri Meri', 'Superhero paperfan decorations from
# The Original Party Bag Company', 'Superhero-themed party bags and plate ware from Daydream Society', 'Themed bouncy
# castle, games, balloon modeling, and disco music from A Superhero World'], 'entertainment': ['Interactive superhero
# games with Spider-Man, Batman, Superman, etc., from Absolutely Amazing Parties', 'Superhero-themed party host with
# games, prizes, and dancing from Bella Parties', 'Superhero mascots appearances and activities from Mascot
# Moments'], 'catering': ["Hero-themed dishes such as 'Power-Up Pizzas' with superhero insignias", 'Kryptonite
# cupcakes with green frosting', 'Hero sandwiches with a variety of fillings', 'Luxury dining experiences from Lyn &
# Louise in Houston', 'Funky mini buffet catering with themed food options']}
# Final answer: {'decorations': ['Dramatic superhero-themed party decorations from Meri Meri', 'Superhero paperfan
# decorations from The Original Party Bag Company', 'Superhero-themed party bags and plate ware from Daydream
# Society', 'Themed bouncy castle, games, balloon modeling, and disco music from A Superhero World'],
# 'entertainment': ['Interactive superhero games with Spider-Man, Batman, Superman, etc., from Absolutely Amazing
# Parties', 'Superhero-themed party host with games, prizes, and dancing from Bella Parties', 'Superhero mascots
# appearances and activities from Mascot Moments'], 'catering': ["Hero-themed dishes such as 'Power-Up Pizzas' with
# superhero insignias", 'Kryptonite cupcakes with green frosting', 'Hero sandwiches with a variety of fillings',
# 'Luxury dining experiences from Lyn & Louise in Houston', 'Funky mini buffet catering with themed food options']}
# [Step 5: Duration 16.77 seconds| Input tokens: 21,878 | Output tokens: 794]
# {'decorations': ['Dramatic superhero-themed party decorations from Meri Meri', 'Superhero paperfan decorations from The Original Party Bag Company', 'Superhero-themed party bags and plate ware from Daydream Society', 'Themed bouncy castle, games, balloon modeling, and disco music from A Superhero World'], 'entertainment': ['Interactive superhero games with Spider-Man, Batman, Superman, etc., from Absolutely Amazing Parties', 'Superhero-themed party host with games, prizes, and dancing from Bella Parties', 'Superhero mascots appearances and activities from Mascot Moments'], 'catering': ["Hero-themed dishes such as 'Power-Up Pizzas' with superhero insignias", 'Kryptonite cupcakes with green frosting', 'Hero sandwiches with a variety of fillings', 'Luxury dining experiences from Lyn & Louise in Houston', 'Funky mini buffet catering with themed food options']}

# %% [markdown]
# ## The agent follows this process:
#
# * **Analyzes the Request**: Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# * **Performs Retrieval**: The agent leverages DuckDuckGoSearchTool to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# * **Synthesizes Information**: After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# * **Stores for Future Reference**: The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks.

# %% [markdown]
# ## Custom Knowledge Base Tool
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
# !pip install git+ssh://git@github.com/dorianbrown/rank_bm25.git
# Out:
# Collecting git+ssh://****@github.com/dorianbrown/rank_bm25.git
#   Cloning ssh://****@github.com/dorianbrown/rank_bm25.git to /private/var/folders/rm/fz529fmj7rx00c8g4s7mbvsc0000gp/T/pip-req-build-k3_mlt29
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/dorianbrown/rank_bm25.git' /private/var/folders/rm/fz529fmj7rx00c8g4s7mbvsc0000gp/T/pip-req-build-k3_mlt29
#   Resolved ssh://****@github.com/dorianbrown/rank_bm25.git to commit 47aa3ddf8dc1ebeb7ef4e65f2b4536af44594099
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from rank_bm25==0.2.2.post6) (1.26.4)
# Building wheels for collected packages: rank_bm25
#   Building wheel for rank_bm25 (pyproject.toml) ... done
#   Created wheel for rank_bm25: filename=rank_bm25-0.2.2.post6-py3-none-any.whl size=8883 sha256=5acaf3643142252f0b7882d736e4aab64e7e578e2380409dc04000b4c3a651cd
#   Stored in directory: /private/var/folders/rm/fz529fmj7rx00c8g4s7mbvsc0000gp/T/pip-ephem-wheel-cache-0f7dnhss/wheels/f0/36/ea/d203455084fc9db0e4745b8d35f1e0431e7e2b0df933333764
# Successfully built rank_bm25
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2.post6
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install langchain_text_splitters
# Out:
# Requirement already satisfied: langchain_text_splitters in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain_text_splitters) (1.2.24)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.7.24)
# Requirement already satisfied: packaging>=23.2.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.33.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.25.0)
# Requirement already satisfied: anyio in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (4.12.1)
# Requirement already satisfied: certifi in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: idna in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/clean_zaid/Documents/Home/Backups/BOOKS/Trillionaire/Python/jupyter-notebooks/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.6.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_community.docstore.document import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = (
    "Uses semantic search to retrieve relevant party planning ideas for "
    "Alfred's superhero-themed party at Wayne Manor. "
    "Returns a single formatted string containing the top matching ideas. "
    "The output is ready to use as-is — do not split or parse it further."
    )
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)

docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",  # Non-thinking variant, supports tool calling
    # token="hf_..."  # Add your HF token if hitting auth errors
)


# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=model)

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   ideas = party_planning_retriever(query="luxury superhero-themed party ideas entertainment catering
#   decorations")
#   print(ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 3.91 seconds| Input tokens: 2,131 | Output tokens: 67]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Summarizing the ideas
#   decoration_options = [
#       "Luxury decor with gold accents and velvet curtains",
#       "Iconic superhero logos displayed around the venue",
#       "Projections of Gotham and other superhero cities"
#   ]
#
#   entertainment_options = [
#       "Superhero-themed masquerade ball",
#       "Interactive VR experiences engaging in superhero simulations or themed games",
#       "Professional DJ playing themed music for superheroes"
#   ]
#
#   catering_options = [
#       "Dishes named after superheroes, such as 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'"
#   ]
#
#   # Creating a summary
#   summary = {
#       "decorations": decoration_options,
#       "entertainment": entertainment_options,
#       "catering": catering_options
#   }
#
#   # Printing the summary
#   print(summary)
#
#   # Returning the final answer
#   final_answer(summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'decorations': ['Luxury decor with gold accents and velvet curtains', 'Iconic superhero logos displayed around the
# venue', 'Projections of Gotham and other superhero cities'], 'entertainment': ['Superhero-themed masquerade ball',
# 'Interactive VR experiences engaging in superhero simulations or themed games', 'Professional DJ playing themed
# music for superheroes'], 'catering': ["Dishes named after superheroes, such as 'The Hulk's Green Smoothie' and
# 'Iron Man's Power Steak'"]}
# Final answer: {'decorations': ['Luxury decor with gold accents and velvet curtains', 'Iconic superhero logos
# displayed around the venue', 'Projections of Gotham and other superhero cities'], 'entertainment':
# ['Superhero-themed masquerade ball', 'Interactive VR experiences engaging in superhero simulations or themed
# games', 'Professional DJ playing themed music for superheroes'], 'catering': ["Dishes named after superheroes, such
# as 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'"]}
# [Step 2: Duration 9.03 seconds| Input tokens: 4,544 | Output tokens: 284]
# {'decorations': ['Luxury decor with gold accents and velvet curtains', 'Iconic superhero logos displayed around the venue', 'Projections of Gotham and other superhero cities'], 'entertainment': ['Superhero-themed masquerade ball', 'Interactive VR experiences engaging in superhero simulations or themed games', 'Professional DJ playing themed music for superheroes'], 'catering': ["Dishes named after superheroes, such as 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'"]}

# %% [markdown]
# This enhanced agent can:
#
# * First check the documentation for relevant information
# * Combine insights from the knowledge base
# * Maintain conversation context through memory
